# %% [markdown]
# ## Section 6: Data Quality Considerations
#
# Data quality rules ensure that the data loaded into
# the Data Warehouse is clean, complete, and consistent.
#
# ### Rules Applied During ETL:
#
# | Rule | Check | Result |
# |---|---|---|
# | No NULL keys | customer_key, film_key, store_key, date_key | PASSED |
# | No Duplicates | rental_id, payment_id | PASSED |
# | No Negative Amounts | amount >= 0 | PASSED |
# | Late Returns | is_late flag | 40.4% late |
# | Valid Date Range | 2005-05-24 to 2006-02-14 | PASSED |
# | Missing return_date | Removed 183 incomplete rentals | PASSED |
#
# ### Business Insight:
# 40.4% late return rate suggests the business should
# review its rental duration policies.

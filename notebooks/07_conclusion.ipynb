# %% [markdown]
# ## Section 7: Conclusion
#
# ### What We Built
# We transformed an OLTP Movie Rental database (Sakila)
# into a Data Warehouse using dimensional modeling.
#
# ### Deliverables
#
# | Deliverable | Details |
# |---|---|
# | Fact Tables | fact_rental (15,861 rows), fact_payment (16,044 rows) |
# | Dimension Tables | dim_date, dim_customer, dim_film, dim_category, dim_store, dim_staff, dim_actor, dim_location |
# | Schema Type | Star Schema |
# | ETL Process | Extract → Transform → Load |
# | Data Quality | 5 rules — all passed |
# | Visualizations | Top Films, Revenue by Store, Late vs On-time Returns |
#
# ### Key Findings
# - Total Revenue: $67,406.56
# - Most Popular Category: Sports (1,179 rentals)
# - Top Film: BUCKET BROTHERHOOD (34 rentals)
# - Late Returns: 40.4% of all rentals
# - Store 1 Revenue: $33,482.50
# - Store 2 Revenue: $33,924.06
#
# ### How This Supports Business Decisions
# The Data Warehouse reduces complex 6-table OLTP joins
# into simple 2-table queries, making business analysis
# faster, easier, and more accurate.
